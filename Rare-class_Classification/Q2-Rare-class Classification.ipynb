# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
input_data = pd.read_csv("SouthGermanCredit.csv")

# %% [markdown]
# # Data exploration

# %%
# i changed the column names to english by considering the description from the provided website
input_data.head()
# Out:
#    status  duration  credit_history  purpose  amount  savings  \
# 0       1        18               4        2    1049        1
# 1       1         9               4        0    2799        1
# 2       2        12               2        9     841        2
# 3       1        12               4        0    2122        1
# 4       1        12               4        0    2171        1
#
#    employment_duration  installment_rate  personal_status_sex  other_debtors  \
# 0                    2                 4                    2              1
# 1                    3                 2                    3              1
# 2                    4                 2                    2              1
# 3                    3                 3                    3              1
# 4                    3                 4                    3              1
#
#    ...  property  age  other_installment_plans  housing  number_credits  job  \
# ...

# %%
input_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   status                   1000 non-null   int64
#  1   duration                 1000 non-null   int64
#  2   credit_history           1000 non-null   int64
#  3   purpose                  1000 non-null   int64
#  4   amount                   1000 non-null   int64
#  5   savings                  1000 non-null   int64
#  6   employment_duration      1000 non-null   int64
#  7   installment_rate         1000 non-null   int64
#  8   personal_status_sex      1000 non-null   int64
#  9   other_debtors            1000 non-null   int64
#  10  present_residence        1000 non-null   int64
#  11  property                 1000 non-null   int64
#  12  age                      1000 non-null   int64
#  13  other_installment_plans  1000 non-null   int64
# ...

# %%
input_data.describe()
# Out:
#             status     duration  credit_history      purpose       amount  \
# count  1000.000000  1000.000000      1000.00000  1000.000000   1000.00000
# mean      2.577000    20.903000         2.54500     2.828000   3271.24800
# std       1.257638    12.058814         1.08312     2.744439   2822.75176
# min       1.000000     4.000000         0.00000     0.000000    250.00000
# 25%       1.000000    12.000000         2.00000     1.000000   1365.50000
# 50%       2.000000    18.000000         2.00000     2.000000   2319.50000
# 75%       4.000000    24.000000         4.00000     3.000000   3972.25000
# max       4.000000    72.000000         4.00000    10.000000  18424.00000
#
#            savings  employment_duration  installment_rate  \
# count  1000.000000          1000.000000       1000.000000
# mean      2.105000             3.384000          2.973000
# std       1.580023             1.208306          1.118715
# min       1.000000             1.000000          1.000000
# ...

# %%
print(input_data.apply(lambda col:col.unique()))
# Out:
# status                                                          [1, 2, 4, 3]
# duration                   [18, 9, 12, 10, 8, 6, 24, 11, 30, 48, 36, 15, ...
# credit_history                                               [4, 2, 3, 0, 1]
# purpose                                      [2, 0, 9, 3, 1, 10, 5, 4, 6, 8]
# amount                     [1049, 2799, 841, 2122, 2171, 2241, 3398, 1361...
# savings                                                      [1, 2, 3, 5, 4]
# employment_duration                                          [2, 3, 4, 1, 5]
# installment_rate                                                [4, 2, 3, 1]
# personal_status_sex                                             [2, 3, 4, 1]
# other_debtors                                                      [1, 3, 2]
# present_residence                                               [4, 2, 3, 1]
# property                                                        [2, 1, 3, 4]
# ...

# %%
# finding out the number of good and bad credit scores
input_data['credit_risk'].value_counts()
# Out:
# 1    700
# 0    300
# Name: credit_risk, dtype: int64

# %%
# converting 2s to 0s 
convert = ['foreign_worker','telephone','people_liable']
for i in convert:
    input_data[i].replace(2,0, inplace=True)

# %%
print(input_data.apply(lambda col: col.unique()))
# Out:
# status                                                          [1, 2, 4, 3]
# duration                   [18, 9, 12, 10, 8, 6, 24, 11, 30, 48, 36, 15, ...
# credit_history                                               [4, 2, 3, 0, 1]
# purpose                                      [2, 0, 9, 3, 1, 10, 5, 4, 6, 8]
# amount                     [1049, 2799, 841, 2122, 2171, 2241, 3398, 1361...
# savings                                                      [1, 2, 3, 5, 4]
# employment_duration                                          [2, 3, 4, 1, 5]
# installment_rate                                                [4, 2, 3, 1]
# personal_status_sex                                             [2, 3, 4, 1]
# other_debtors                                                      [1, 3, 2]
# present_residence                                               [4, 2, 3, 1]
# property                                                        [2, 1, 3, 4]
# ...

# %%
# finding the missing values in columns
input_data.isna().sum()
# Out:
# status                     0
# duration                   0
# credit_history             0
# purpose                    0
# amount                     0
# savings                    0
# employment_duration        0
# installment_rate           0
# personal_status_sex        0
# other_debtors              0
# present_residence          0
# property                   0
# age                        0
# other_installment_plans    0
# housing                    0
# number_credits             0
# job                        0
# people_liable              0
# telephone                  0
# foreign_worker             0
# credit_risk                0
# dtype: int64

# %%
# plotting co-relation matrix
corelation = input_data.corr()
corelation.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_e853d_row0_col0, #T_e853d_row1_col1, #T_e853d_row2_col2, #T_e853d_row3_col3, #T_e853d_row4_col4, #T_e853d_row5_col5, #T_e853d_row6_col6, #T_e853d_row7_col7, #T_e853d_row8_col8, #T_e853d_row9_col9, #T_e853d_row10_col10, #T_e853d_row11_col11, #T_e853d_row12_col12, #T_e853d_row13_col13, #T_e853d_row14_col14, #T_e853d_row15_col15, #T_e853d_row16_col16, #T_e853d_row17_col17, #T_e853d_row18_col18, #T_e853d_row19_col19, #T_e853d_row20_col20 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e853d_row0_col1, #T_e853d_row1_col10, #T_e853d_row2_col11, #T_e853d_row3_col9, #T_e853d_row5_col2, #T_e853d_row7_col20, #T_e853d_row10_col13, #T_e853d_row17_col5, #T_e853d_row18_col13 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_e853d_row0_col2, #T_e853d_row12_col7, #T_e853d_row15_col16 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# ...

# %%
# plotting the distribution of the above variables
input_data.hist(figsize = (50,50))
# Out:
# array([[<AxesSubplot: title={'center': 'status'}>,
#         <AxesSubplot: title={'center': 'duration'}>,
#         <AxesSubplot: title={'center': 'credit_history'}>,
#         <AxesSubplot: title={'center': 'purpose'}>,
#         <AxesSubplot: title={'center': 'amount'}>],
#        [<AxesSubplot: title={'center': 'savings'}>,
#         <AxesSubplot: title={'center': 'employment_duration'}>,
#         <AxesSubplot: title={'center': 'installment_rate'}>,
#         <AxesSubplot: title={'center': 'personal_status_sex'}>,
#         <AxesSubplot: title={'center': 'other_debtors'}>],
#        [<AxesSubplot: title={'center': 'present_residence'}>,
#         <AxesSubplot: title={'center': 'property'}>,
#         <AxesSubplot: title={'center': 'age'}>,
#         <AxesSubplot: title={'center': 'other_installment_plans'}>,
#         <AxesSubplot: title={'center': 'housing'}>],
#        [<AxesSubplot: title={'center': 'number_credits'}>,
#         <AxesSubplot: title={'center': 'job'}>,
# ...

# %%
#preparing the copies of the input_data
entireData = input_data
gdf = input_data[input_data['credit_risk']==1]
bdf = input_data[input_data['credit_risk']==0]

# %%
# removing the unncessesary errors
import warnings
warnings.filterwarnings('ignore')
# models for 150,30 and 10 instances
input_data_150 = gdf.append(bdf.sample(150))
input_data_30 = gdf.append(bdf.sample(30))
input_data_10 = gdf.append(bdf.sample(10))
print(input_data_150['credit_risk'].value_counts(), input_data_30['credit_risk'].value_counts(), input_data_10['credit_risk'].value_counts())
# Out:
# 1    700
# 0    150
# Name: credit_risk, dtype: int64 1    700
# 0     30
# Name: credit_risk, dtype: int64 1    700
# 0     10
# Name: credit_risk, dtype: int64

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,precision_score, make_scorer, recall_score, f1_score
from scipy import interp
from sklearn.metrics import auc
from sklearn.metrics import roc_curve
LinearReg = LogisticRegression(solver = 'lbfgs', max_iter = 1000)
test_validation = 0.3
random_no = 79

def model_building(model, X, Y):
    X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = test_validation, random_state = random_no)
    LinearReg.fit(X_train, Y_train)
    Y_pred = LinearReg.predict(X_test)
    print("F1 Score: ", metrics.f1_score(Y_test, Y_pred))
    print("Accuracy: ", metrics.accuracy_score(Y_test, Y_pred))
    print("Precision: ", metrics.precision_score(Y_test, Y_pred))
    print("Recall: ", metrics.recall_score(Y_test, Y_pred))
    
    Y_pred_probability = LinearReg.predict_proba(X_test)[::,1]
    fpr, tpr, _ = metrics.roc_curve(Y_test, Y_pred_probability)
    auc = metrics.roc_auc_score(Y_test, Y_pred_probability)
    print("Area Under Curve: "+ str(auc))
    
    plt.plot(fpr, tpr, label = "data , auc = "+ str(auc))
    plt.legend(loc=4)
    plt.show()

# %%
#splitting dependent variable and target variable on entireData
X = entireData.iloc[:,:-1].values
Y = entireData.iloc[:,-1].values
model_building(LinearReg, X, Y)
# Out:
# F1 Score:  0.8237986270022882
# Accuracy:  0.7433333333333333
# Precision:  0.75
# Recall:  0.9137055837563451
# Area Under Curve: 0.7942930363215218

# %%
# splitting dependent variables and target variable on 150 bad credit scores
X = input_data_150.iloc[:, :-1].values
Y = input_data_150.iloc[:, -1].values
model_building(LinearReg, X, Y)
# Out:
# F1 Score:  0.9151785714285714
# Accuracy:  0.8509803921568627
# Precision:  0.8613445378151261
# Recall:  0.9761904761904762
# Area Under Curve: 0.7128042328042329

# %%
# splitting dependent variables and target variable on 30 bad credit scores
X = input_data_30.iloc[:, :-1].values
Y = input_data_30.iloc[:, -1].values
model_building(LinearReg, X, Y)
# Out:
# F1 Score:  0.9812206572769953
# Accuracy:  0.9634703196347032
# Precision:  0.9675925925925926
# Recall:  0.9952380952380953
# Area Under Curve: 0.7238095238095239

# %%
# splitting dependent variables and target variable on 10 bad credit scores
X = input_data_10.iloc[:, :-1].values
Y = input_data_10.iloc[:, -1].values
model_building(LinearReg, X, Y)
# Out:
# F1 Score:  0.990521327014218
# Accuracy:  0.9812206572769953
# Precision:  0.9812206572769953
# Recall:  1.0
# Area Under Curve: 0.8026315789473684

# %% [markdown]
# # Building model for 2C

# %%
input_data['personal_status_sex'].value_counts()
# Out:
# 3    548
# 2    310
# 4     92
# 1     50
# Name: personal_status_sex, dtype: int64

# %%
# grouping the input data
df1 = input_data[input_data['personal_status_sex']==1]
df2 = input_data[input_data['personal_status_sex']==2]
df3 = input_data[input_data['personal_status_sex']==3]
df4 = input_data[input_data['personal_status_sex']==4]

# %%
print(df1['personal_status_sex'].value_counts())
# Out:
# 1    50
# Name: personal_status_sex, dtype: int64

# %%
print(df2['personal_status_sex'].value_counts())
# Out:
# 2    310
# Name: personal_status_sex, dtype: int64

# %%
print(df3['personal_status_sex'].value_counts())
# Out:
# 3    548
# Name: personal_status_sex, dtype: int64

# %%
print(df4['personal_status_sex'].value_counts())
# Out:
# 4    92
# Name: personal_status_sex, dtype: int64

# %%
LinearReg = LogisticRegression(solver = 'lbfgs', max_iter = 1000)
test_validation = 0.7
random_no = 97

def model_building(model, X_train, Y_train, X_test, Y_test):
    LinearReg.fit(X_train, Y_train)
    Y_pred = LinearReg.predict(X_test)
    print("F1 Score: ", metrics.f1_score(Y_test, Y_pred))
    print("Accuracy: ", metrics.accuracy_score(Y_test, Y_pred))
    print("Precision: ", metrics.precision_score(Y_test, Y_pred))
    print("Recall: ", metrics.recall_score(Y_test, Y_pred))
    
    Y_pred_probability = LinearReg.predict_proba(X_test)[::,1]
    fpr, tpr, _ = metrics.roc_curve(Y_test, Y_pred_probability)
    auc = metrics.roc_auc_score(Y_test, Y_pred_probability)
    print("Area Under Curve: "+ str(auc))
    
    plt.plot(fpr, tpr, label = "data , auc = "+ str(auc))
    plt.legend(loc=4)
    plt.show()

# %% [markdown]
# # 2d

# %%
#splitting target and dependent variables
# famges : 'personal_status_sex'
X_train = df2.iloc[:, :-1].values
Y_train = df2.iloc[:, -1].values
X_test = df1.iloc[:, :-1].values
Y_test = df1.iloc[:, -1].values

print("results of personal_status_sex : non-single/male :single with respect to male : divorse/seperated")
model_building(LinearReg, X_train, Y_train, X_test, Y_test)
# Out:
# results of personal_status_sex : non-single/male :single with respect to male : divorse/seperated
# F1 Score:  0.7428571428571429
# Accuracy:  0.64
# Precision:  0.65
# Recall:  0.8666666666666667
# Area Under Curve: 0.6866666666666666

# %%
X_test = df3.iloc[:, :-1].values
Y_test = df3.iloc[:, -1].values

print("results of personal_status_sex : non-single/male :single with respect to male : married/widowed")
model_building(LinearReg, X_train, Y_train, X_test, Y_test)
# Out:
# results of personal_status_sex : non-single/male :single with respect to male : married/widowed
# F1 Score:  0.8042049934296978
# Accuracy:  0.7281021897810219
# Precision:  0.8523676880222841
# Recall:  0.7611940298507462
# Area Under Curve: 0.7695767736659169

# %%
X_test = df4.iloc[:, :-1].values
Y_test = df4.iloc[:, -1].values

print("results of personal_status_sex : non-single/male :single with respect to female : single")
model_building(LinearReg, X_train, Y_train, X_test, Y_test)
# Out:
# results of personal_status_sex : non-single/male :single with respect to female : single
# F1 Score:  0.7500000000000001
# Accuracy:  0.6739130434782609
# Precision:  0.8490566037735849
# Recall:  0.6716417910447762
# Area Under Curve: 0.693134328358209

# %%
# famges : 'personal_status_sex'
X_train = df4.iloc[:, :-1].values
Y_train = df4.iloc[:, -1].values
X_test = df1.iloc[:, :-1].values
Y_test = df1.iloc[:, -1].values

print("results of personal_status_sex : female :single with respect to male : divorse/seperated")
model_building(LinearReg, X_train, Y_train, X_test, Y_test)
# Out:
# results of personal_status_sex : female :single with respect to male : divorse/seperated
# F1 Score:  0.7826086956521738
# Accuracy:  0.7
# Precision:  0.6923076923076923
# Recall:  0.9
# Area Under Curve: 0.6966666666666667

# %%
X_test = df2.iloc[:, :-1].values
Y_test = df2.iloc[:, -1].values

print("results of personal_status_sex : female :single with respect to non-single/male :single")
model_building(LinearReg, X_train, Y_train, X_test, Y_test)
# Out:
# results of personal_status_sex : female :single with respect to non-single/male :single
# F1 Score:  0.7918552036199095
# Accuracy:  0.7032258064516129
# Precision:  0.7261410788381742
# Recall:  0.8706467661691543
# Area Under Curve: 0.6974302797936921

# %%
X_test = df3.iloc[:, :-1].values
Y_test = df3.iloc[:, -1].values

print("results of personal_status_sex : female :single with respect to male : married/widowed")
model_building(LinearReg, X_train, Y_train, X_test, Y_test)
# Out:
# results of personal_status_sex : female :single with respect to male : married/widowed
# F1 Score:  0.8347205707491082
# Accuracy:  0.7463503649635036
# Precision:  0.7995444191343963
# Recall:  0.8731343283582089
# Area Under Curve: 0.716298643767464

# %% [markdown]
# # Q3

# %%
from interpret import show
from interpret.data import Marginal
from dash.dash_table.Format import Group
import dash_table as dt

X = entireData.iloc[:, :-1].values
Y = entireData.iloc[:, -1].values
marginal = Marginal().explain_data(X,Y, name = 'Data')
show(marginal)
# Out:
# <!-- http://127.0.0.1:7001/5456576272/ -->
# <iframe src="http://127.0.0.1:7001/5456576272/" width=100% height=800 frameBorder="0"></iframe>

# %%
print(df1['credit_risk'].value_counts())
# Out:
# 1    30
# 0    20
# Name: credit_risk, dtype: int64

# %%
print(df2['credit_risk'].value_counts())
# Out:
# 1    201
# 0    109
# Name: credit_risk, dtype: int64

# %%
print(df3['credit_risk'].value_counts())
# Out:
# 1    402
# 0    146
# Name: credit_risk, dtype: int64

# %%
print(df4['credit_risk'].value_counts())
# Out:
# 1    67
# 0    25
# Name: credit_risk, dtype: int64
